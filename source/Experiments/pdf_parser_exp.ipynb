# %%
from langchain_unstructured import UnstructuredLoader

file = r"C:\Users\deepa\Downloads\Deepanshu Bhatt\rerprCheck-NLP-base-Biomedical-Research-Checklist-\Data\raw\pmc_pdfs\rsob.240345.pdf"
loader = UnstructuredLoader(file, mode="elements", strategy="fast")

docs = loader.load()  # this is a list of Document objects

# Combine all text
full_text = "\n\n".join([d.page_content for d in docs])

# Save to a txt file
output_file = "rsob_240345.txt"
with open(output_file, "w", encoding="utf-8") as f:
    f.write(full_text)

print(f"✅ Extracted text saved to {output_file}")
# Out:
# INFO: pikepdf C++ to Python logger bridge initialized
# ...
# ✅ Extracted text saved to rsob_240345.txt

# %%
with open("rsob_240345.txt", "r", encoding = "utf-8") as f:
    text = f.read()

# %%
file = r"C:\Users\deepa\Downloads\Deepanshu Bhatt\rerprCheck-NLP-base-Biomedical-Research-Checklist-\Data\raw\pmc_pdfs\rsob.240345.pdf"
loader = UnstructuredLoader(file, mode="elements", strategy="hi_res", coordinates = True)
docs = []
for doc in loader.lazy_load():
    docs.append(doc)
# Out:
# ...
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING: Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# yolox_l0.05.onnx:   0%|          | 0.00/217M [00:00<?, ?B/s]
# INFO: Reading PDF for file: C:\Users\deepa\Downloads\Deepanshu Bhatt\rerprCheck-NLP-base-Biomedical-Research-Checklist-\Data\raw\pmc_pdfs\rsob.240345.pdf ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ...
